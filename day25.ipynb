# %%
# Day 25 Advent of Code

# %%
def parse(input_file):
    with open(input_file) as fp:
        lines = fp.read().splitlines()
    return [list(i) for i in lines]

def print_cucumbers(cucumbers):
    height = len(cucumbers)
    width = len(cucumbers[0])
    print("\n")
    for r in range(height):
        print("".join(cucumbers[r][c] for c in range(width)))
    print("\n")

def move_cucumbers(cucumbers, debug=False):
    height = len(cucumbers)
    width = len(cucumbers[0])
    steps = 1 # initial grid 
    while True:
        steps += 1
        east = set()
        south = set()
        next_grid = [[cucumbers[r][c] for c in range(width)] for r in range(height)]
        for r in range(height):
            for c in range(width):
                next_c = (c + 1) % width
                if cucumbers[r][c] == '>' and cucumbers[r][next_c] == '.':
                    east.add((r,c))
                    next_grid[r][next_c] = '>'
                    next_grid[r][c] = '.'
        for r in range(height):
            next_r = (r + 1) % height
            for c in range(width):
                if next_grid[r][c] == 'v' and next_grid[next_r][c] == '.':
                    south.add((r,c))
                    next_grid[next_r][c] = 'v'
                    next_grid[r][c] = '.'
        if debug:
            print("Step %d: >: %d, v: %d" % (steps, len(east), len(south)))
            print_cucumbers(cucumbers)
        if len(east | south) == 0:
            return(steps)
        cucumbers = next_grid

# %%
cucumbers = parse("input_files/day25.test.txt")

print(move_cucumbers(cucumbers, True))
# Out:
# Step 2: >: 10, v: 26
#
#
# v...>>.vv>
# .vv>>.vv..
# >>.>v>...v
# >>v>>.>.v.
# v>v.vv.v..
# >.>>..v...
# .vv..>.>v.
# v.v..>>v.v
# ....v..v.>
#
#
# Step 3: >: 10, v: 17
#
#
# .vv.>.>vv>
# v.v>.>v...
# >v>>..>vv.
# >>v>v>.>..
# .>v.v.....
# .>>.>.vvv.
# v.v..v>>.v
# v....>>v..
# >...v..v.v
#
#
# Step 4: >: 9, v: 22
#
#
# >.v.v>>v.v
# vvv.>>vvv.
# >v>.>.>.v.
# >>v>v.>.>.
# .>.....v..
# .>v>.>v.v.
# v....v>v>.
# ....v>>v.v
# v>v.......
#
#
# Step 5: >: 10, v: 12
#
#
# v>v.v>>vvv
# vv..>>.vv.
# >vv>.>.>.v
# >>v>...>.>
# ..>.v.v.v.
# .>..>>vv..
# .....v>v.>
# v.v..>>...
# .>v.v..v..
#
#
# Step 6: >: 11, v: 12
#
#
# v>v.v>>vv.
# vvv.>.>.vv
# >vv.>.>.>v
# >>..>...>>
# ..v>v.vv..
# ..>.>>vv..
# >....v>v..
# ..v..>.>..
# v>..v..vv.
#
#
# Step 7: >: 9, v: 13
#
#
# v>v.v>>vv.
# vvv..>.>vv
# >.v..>.>>v
# >.>.v>..>>
# ...>v.vv..
# .v.>>>vv..
# .>v...>...
# ..v...>v>.
# v.>..v.vv.
#
#
# Step 8: >: 7, v: 12
#
#
# v>v..>>vv.
# .vv...>>vv
# .>..v.>>>v
# .>.>v.>.>>
# ...>v.vv..
# .vv>>>.v..
# .>v...v>..
# v.....>v.>
# v.v>.v.vv.
#
#
# Step 9: >: 7, v: 19
#
#
# v>v..>>vv.
# ..v...>>vv
# v.>.v.>>>.
# >.>>v..>>.
# .v.>v.vv..
# .vv>>.>...
# .>....vv>v
# v.v...>v.>
# ..v.>v.vv.
#
#
# Step 10: >: 9, v: 17
#
#
# v>v..>>vv.
# v.....>>.v
# ..v>v.>>.>
# .>>>v..>.>
# .v.>...v..
# ..v>.>v>v.
# v.>...vv>v
# ..v.v.>v.>
# .vv.>v.vv.
#
#
# Step 11: >: 9, v: 11
#
#
# v>v..>>vvv
# v.v...>.>.
# >.v>v.>.>.
# >>>>v..v>.
# ....>..v..
# ....>>v>vv
# v.v>..vv>.
# >vv.v.>v..
# .v..>v..v.
#
#
# Step 12: >: 8, v: 9
#
#
# v>v..>>vvv
# ..v....>.>
# v>v>v..>.>
# >>>>...v.>
# ....v>.vv.
# ....>>v>.v
# v.v.>.vv.>
# >v..v.>.v.
# .vv.>v.v..
#
#
# Step 13: >: 6, v: 10
#
#
# v>v..>>vv.
# >.v.....>v
# v>v>v..v>>
# >>>.>..v.>
# ....v.>.v.
# ....>>vv>v
# v....>.v.>
# >vv.v..>..
# .vv.>vv.v.
#
#
# Step 14: >: 6, v: 2
#
#
# .>v..>>vv.
# v>v....v>v
# v>.>...v>>
# >>.>v>.v.>
# ....v..>v.
# ....>>vv>v
# v.v...>..>
# >vv.v...>.
# .vv.>vv.v.
#
#
# Step 15: >: 5, v: 7
#
#
# .>v..>>vv.
# v>v....v>v
# v.>.>..v>>
# >.>>v.>v.>
# ....v..>v.
# ....>>.v>v
# v.v....>.>
# >vv.v.v..>
# .vv.>vv.v.
#
#
# Step 16: >: 7, v: 5
#
#
# .>v..>>vv.
# v>.....v>v
# ..v>.>.v>>
# .>>>v.>v.>
# ....v..>v.
# v...>.>.>v
# v.v.....>>
# >vv.v.v..>
# .vv.>vvvv.
#
#
# Step 17: >: 6, v: 9
#
#
# .>v..>>vv.
# v.>....v>.
# >.v.>.>v>.
# >>>>v.>v..
# .......>vv
# v....>.>>v
# v.v.v...>>
# >vv.v.v..>
# .vv.>vvvv.
#
#
# Step 18: >: 3, v: 3
#
#
# .>v..>>vv.
# ..v>...v.>
# v>v..>>v.>
# >>>>..>vv.
# .......>vv
# v...v.>>>v
# v.v.v...>>
# >vv.v.v..>
# .v..>vvv..
#
#
# Step 19: >: 4, v: 4
#
#
# .>v..>>v..
# >.v.>..v..
# v>v..>>vv>
# >>>.>.>vv.
# .......>vv
# v...v.>>>v
# v.v.v...>>
# >v..v.v..>
# .vv.>vvv..
#
#
# Step 20: >: 4, v: 1
#
#
# .>v..>>v..
# .>v..>.v..
# v>...>>vv>
# >>.>.>>vv.
# .......>vv
# v.v.v.>>>v
# v...v...>>
# >vv.v.v..>
# .vv.>vvv..
#
#
# Step 21: >: 3, v: 6
#
#
# .>v..>>v..
# .>v...>v..
# v.>..>>vv>
# >.>.>>>vv.
# .......>vv
# v...v.>>>v
# v.v.v...>>
# >vv.v.v..>
# .vv.>vvv..
#
#
# Step 22: >: 4, v: 0
#
#
# .>v..>>v..
# .>....>v..
# ...>.>>vv>
# .>.>>>>vv.
# v......>vv
# v.v.v.>>>v
# v.v.v...>>
# >vv.v.v..>
# .vv.>vvv..
#
#
# Step 23: >: 2, v: 3
#
#
# .>v..>>v..
# ..>...>v..
# >...>>>vv.
# ..>>>>>vv.
# v......>vv
# v.v.v.>>>v
# v.v.v...>>
# >vv.v.v..>
# .vv.>vvv..
#
#
# Step 24: >: 1, v: 3
#
#
# .>v..>>v..
# ...>..>v..
# .>v.>>>vv.
# ..>>>>>vv.
# v......>vv
# v.v.v.>>>v
# v.v.v...>>
# >vv.v.v..>
# .v..>vvv..
#
#
# Step 25: >: 1, v: 2
#
#
# .>v..>>v..
# ..v.>.>v..
# .>v.>>>vv.
# ..>>>>>vv.
# v......>vv
# v.v.v.>>>v
# v.v.v...>>
# >v..v.v..>
# .v..>vvv..
#
#
# Step 26: >: 0, v: 2
#
#
# .>v..>>v..
# ..v..>>v..
# .>v.>>>vv.
# ..>>>>>vv.
# v......>vv
# v.v.v.>>>v
# v...v...>>
# >v..v.v..>
# .vv.>vvv..
#
#
# Step 27: >: 0, v: 0
#
#
# .>v..>>v..
# ..v..>>v..
# .>v.>>>vv.
# ..>>>>>vv.
# v......>vv
# v...v.>>>v
# v...v...>>
# >vv.v.v..>
# .vv.>vvv..
#
#
# 27

# %%
cucumbers = parse("input_files/day25.txt")
print(move_cucumbers(cucumbers))
# Out:
# 474
